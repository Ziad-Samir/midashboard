# %%
import pandas as pd 
import numpy  as np
import dash

# %%
df=pd.read_csv('../data/healthcare_dataset.csv')
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'], errors='coerce')
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'], errors='coerce')

# %%
df['lenght Of Stay']=df['Discharge Date']-df['Date of Admission']
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# lenght Of Stay        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(534)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                 Age              Date of Admission  Billing Amount  \
# count  54966.000000                          54966    54966.000000
# mean      51.535185  2021-11-01 17:35:29.505512448    25544.306284
# min       13.000000            2019-05-08 00:00:00    -2008.492140
# 25%       35.000000            2020-07-28 00:00:00    13243.718641
# 50%       52.000000            2021-11-02 00:00:00    25542.749145
# 75%       68.000000            2023-02-03 00:00:00    37819.858159
# max       89.000000            2024-05-07 00:00:00    52764.276736
# std       19.605661                            NaN    14208.409711
#
#         Room Number                 Discharge Date              lenght Of Stay
# count  54966.000000                          54966                       54966
# mean     301.124404  2021-11-17 05:34:28.202161408  15 days 11:58:58.696648837
# min      101.000000            2019-05-09 00:00:00             1 days 00:00:00
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results', 'lenght Of Stay'],
#       dtype='object')

# %%
df.groupby('Hospital')['lenght Of Stay'].sum().reset_index().nlargest(10, 'lenght Of Stay')
# Out:
#           Hospital lenght Of Stay
# 16879    LLC Smith       685 days
# 18590    Ltd Smith       644 days
# 28908    Smith PLC       635 days
# 28850  Smith Group       612 days
# 14869  Johnson PLC       597 days
# 28888    Smith Ltd       560 days
# 10883  Group Smith       522 days
# 28881    Smith LLC       515 days
# 16662  LLC Johnson       511 days
# 28871    Smith Inc       508 days

# %%
df['Hospital'].nunique()
# Out:
# 39876

# %%
df['Hospital'].describe()
# Out:
# count         54966
# unique        39876
# top       LLC Smith
# freq             44
# Name: Hospital, dtype: object

# %%
df['Hospital'].value_counts()>5
# Out:
# Hospital
# LLC Smith                        True
# Ltd Smith                        True
# Smith Ltd                        True
# Johnson PLC                      True
# Smith Group                      True
#                                 ...
# James-Owen                      False
# Marks, and Vazquez Jenkins      False
# Sons and Webster                False
# and Cox, Lawrence Grimes        False
# Thornton and Nguyen Freeman,    False
# Name: count, Length: 39876, dtype: bool

# %%
hospital_counts = df['Hospital'].value_counts()
hospital_counts
# Out:
# Hospital
# LLC Smith                       44
# Ltd Smith                       39
# Smith Ltd                       37
# Johnson PLC                     37
# Smith Group                     36
#                                 ..
# James-Owen                       1
# Marks, and Vazquez Jenkins       1
# Sons and Webster                 1
# and Cox, Lawrence Grimes         1
# Thornton and Nguyen Freeman,     1
# Name: count, Length: 39876, dtype: int64

# %%
hospitals_to_keep= hospital_counts[hospital_counts > 5].index
hospitals_to_keep
# Out:
# Index(['LLC Smith', 'Ltd Smith', 'Smith Ltd', 'Johnson PLC', 'Smith Group',
#        'Smith PLC', 'Johnson Inc', 'Smith Inc', 'Group Smith', 'Smith LLC',
#        ...
#        'Parker Group', 'Sons Martin and', 'Wood Inc', 'LLC Stone', 'Evans Inc',
#        'Myers PLC', 'Edwards PLC', 'Hansen PLC', 'Ltd Reyes', 'Ltd Baker'],
#       dtype='object', name='Hospital', length=545)

# %%
df = df[df['Hospital'].isin(hospitals_to_keep)]

# %%
df.describe()
# Out:
#                Age              Date of Admission  Billing Amount  \
# count  5592.000000                           5592     5592.000000
# mean     51.130544  2021-10-29 22:48:40.171673856    25522.964354
# min      14.000000            2019-05-08 00:00:00    -1520.420555
# 25%      34.000000            2020-07-23 00:00:00    13080.873414
# 50%      52.000000            2021-10-31 00:00:00    25682.536853
# 75%      68.000000            2023-02-05 06:00:00    37830.803121
# max      89.000000            2024-05-07 00:00:00    52764.276736
# std      19.463942                            NaN    14223.995080
#
#        Room Number                 Discharge Date              lenght Of Stay
# count  5592.000000                           5592                        5592
# mean    301.546495  2021-11-14 10:56:08.240343552  15 days 12:07:28.068669528
# min     101.000000            2019-05-13 00:00:00             1 days 00:00:00
# ...

# %%
df['Hospital'].value_counts().reset_index()
# Out:
#              Hospital  count
# 0           LLC Smith     44
# 1           Ltd Smith     39
# 2         Johnson PLC     37
# 3           Smith Ltd     37
# 4         Smith Group     36
# ..                ...    ...
# 540         Scott Inc      6
# 541      PLC Martinez      6
# 542  Sons and Jackson      6
# 543          Ltd Hale      6
# 544       Inc Schmidt      6
#
# [545 rows x 2 columns]

# %%
df[df['Name']=='cathERinE gArDnEr']
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 95     cathERinE gArDnEr   79  Female         A-      Hypertension
# 50851  cathERinE gArDnEr   75  Female         A-      Hypertension
#
#       Date of Admission      Doctor   Hospital Insurance Provider  \
# 95           2019-08-19  David Ruiz  James Ltd           Medicare
# 50851        2019-08-19  David Ruiz  James Ltd           Medicare
#
#        Billing Amount  Room Number Admission Type Discharge Date Medication  \
# 95       25503.673807          144       Elective     2019-08-26    Lipitor
# 50851    25503.673807          144       Elective     2019-08-26    Lipitor
#
#       Test Results lenght Of Stay
# 95        Abnormal         7 days
# 50851     Abnormal         7 days

# %%
df['Name'].drop_duplicates(inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9352\2143826969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'].drop_duplicates(inplace=True)

# %%
df.drop_duplicates(subset='Name', keep='first', inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9352\964551187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset='Name', keep='first', inplace=True)

# %%
df['Medical Condition'].value_counts()
# Out:
# Medical Condition
# Hypertension    859
# Arthritis       849
# Obesity         830
# Cancer          830
# Diabetes        828
# Asthma          788
# Name: count, dtype: int64

# %%
import plotly.express as px

# %%
help(px.pie)
# Out:
# Help on function pie in module plotly.express._chart_types:
#
# pie(
#     data_frame=None,
#     names=None,
#     values=None,
#     color=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     category_orders=None,
#     labels=None,
#     title=None,
#     subtitle=None,
#     template=None,
#     width=None,
#     height=None,
#     opacity=None,
#     hole=None
# ) -> plotly.graph_objs._figure.Figure
#     In a pie plot, each row of `data_frame` is represented as a sector of a
#     pie.
#
#     Parameters
#     ----------
#     data_frame: DataFrame or array-like or dict
#         This argument needs to be passed for column names (and not keyword
#         names) to be used. Array-like and dict are transformed internally to a
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results', 'lenght Of Stay'],
#       dtype='object')

# %%
#px.pie(data_frame=df,names='medica')

# %%
df.describe()
# Out:
#                Age              Date of Admission  Billing Amount  \
# count  4984.000000                           4984     4984.000000
# mean     51.276685  2021-10-31 20:26:11.749598720    25481.077870
# min      18.000000            2019-05-08 00:00:00    -1520.420555
# 25%      34.000000            2020-07-26 00:00:00    13035.197321
# 50%      52.000000            2021-11-04 12:00:00    25562.707794
# 75%      68.000000            2023-02-09 00:00:00    37738.708796
# max      85.000000            2024-05-07 00:00:00    52764.276736
# std      19.483721                            NaN    14239.587963
#
#        Room Number                 Discharge Date              lenght Of Stay
# count  4984.000000                           4984                        4984
# mean    300.502207  2021-11-16 08:11:10.304975872  15 days 11:44:58.555377207
# min     101.000000            2019-05-13 00:00:00             1 days 00:00:00
# ...

# %%
df[df['Name'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, Blood Type, Medical Condition, Date of Admission, Doctor, Hospital, Insurance Provider, Billing Amount, Room Number, Admission Type, Discharge Date, Medication, Test Results, lenght Of Stay]
# Index: []

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results', 'lenght Of Stay'],
#       dtype='object')

# %%
fig_Pie=px.pie(data_frame=df,names='Medical Condition')
fig_Pie.update_traces(
    textposition='inside',
    textinfo='label+percent'   # options: 'label', 'percent', 'value', 'none'
)

fig_Pie.show()

# %%
help(fig_Pie.update_traces)
# Out:
# Help on method update_traces in module plotly.graph_objs._figure:
#
# update_traces(
#     patch=None,
#     selector=None,
#     row=None,
#     col=None,
#     secondary_y=None,
#     overwrite=False,
#     **kwargs
# ) -> 'Figure' method of plotly.graph_objs._figure.Figure instance
#     Perform a property update operation on all traces that satisfy the
#     specified selection criteria
#
#     Parameters
#     ----------
#     patch: dict or None (default None)
#         Dictionary of property updates to be applied to all traces that
#         satisfy the selection criteria.
#     selector: dict, function, int, str or None (default None)
#         Dict to use as selection criteria.
#         Traces will be selected if they contain properties corresponding
#         to all of the dictionary's keys, with values that exactly match
#         the supplied values. If None (the default), all traces are
#         selected. If a function, it must be a function accepting a single
# ...

# %%
df.head()
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 0         Bobby JacksOn   30    Male         B-            Cancer
# 1          LesLie TErRy   62    Male         A+           Obesity
# 20        tIMOTHY burNs   67  Female         A-            Asthma
# 23  dR. EilEEn thomPsoN   59    Male         A+            Asthma
# 24       PAUl hEndERsOn   72  Female        AB+      Hypertension
#
#    Date of Admission             Doctor         Hospital Insurance Provider  \
# 0         2024-01-31      Matthew Smith  Sons and Miller         Blue Cross
# 1         2019-08-20    Samantha Davies          Kim Inc           Medicare
# 20        2023-06-28       Krista Smith        Jones LLC         Blue Cross
# 23        2021-08-02  Donna Martinez MD   and Sons Smith              Aetna
# 24        2020-05-15   Stephanie Kramer     Wilson Group           Medicare
#
#     Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
fig_age=px.pie(data_frame=df,names='Gender')
fig_age.update_traces(
    textposition='inside',
    textinfo='label+percent'   # options: 'label', 'percent', 'value', 'none'
)

fig_age.show()

# %%
df['Hospital'].value_counts()
# Out:
# Hospital
# LLC Smith        40
# Ltd Smith        35
# Johnson PLC      35
# Smith Ltd        35
# Smith PLC        33
#                  ..
# Sons Hunt and     4
# Molina Group      4
# Ltd Austin        4
# PLC Obrien        4
# Ltd Hale          4
# Name: count, Length: 545, dtype: int64

# %%
df['Room Number'].nunique()
# Out:
# 400

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results', 'lenght Of Stay'],
#       dtype='object')

# %%
df.groupby('Hospital')['Doctor'].count().reset_index().nlargest(10, 'Doctor').sort_values('Doctor',ascending=False)
# Out:
#         Hospital  Doctor
# 253    LLC Smith      40
# 198  Johnson PLC      35
# 318    Ltd Smith      35
# 452    Smith Ltd      35
# 453    Smith PLC      33
# 449  Smith Group      32
# 106  Group Smith      30
# 195  Johnson Inc      29
# 450    Smith Inc      29
# 237  LLC Johnson      28

# %%
top_hospitals = (
    df.groupby('Hospital')['Doctor']
    .count()
    .reset_index()
    .nlargest(20, 'Doctor')
    ['Hospital']
)

# %%
df_top20=df[df['Hospital'].isin(top_hospitals)]

# %%
df_top20.describe(include='all')
# Out:
#                       Name         Age  Gender Blood Type Medical Condition  \
# count                  580  580.000000     580        580               580
# unique                 580         NaN       2          8                 6
# top     jeFfErY WIlliaMSOn         NaN  Female         B-         Arthritis
# freq                     1         NaN     313         90               109
# mean                   NaN   50.798276     NaN        NaN               NaN
# min                    NaN   18.000000     NaN        NaN               NaN
# 25%                    NaN   34.000000     NaN        NaN               NaN
# 50%                    NaN   52.000000     NaN        NaN               NaN
# 75%                    NaN   66.250000     NaN        NaN               NaN
# max                    NaN   85.000000     NaN        NaN               NaN
# std                    NaN   19.332175     NaN        NaN               NaN
#
# ...

# %%
(df_top20.groupby('Hospital')['Doctor']
.count()
.reset_index()
.sort_values('Doctor',ascending=False)
)
# Out:
#          Hospital  Doctor
# 10      LLC Smith      40
# 17      Smith Ltd      35
# 8     Johnson PLC      35
# 11      Ltd Smith      35
# 18      Smith PLC      33
# 14    Smith Group      32
# 3     Group Smith      30
# 15      Smith Inc      29
# 7     Johnson Inc      29
# 16      Smith LLC      28
# 9     LLC Johnson      28
# 13   PLC Williams      27
# 0       Brown Inc      26
# 12      PLC Smith      26
# 4       Inc Brown      25
# 6       Inc Smith      25
# 19   Williams LLC      25
# 1       Brown LLC      24
# 2   Group Johnson      24
# 5     Inc Johnson      24

# %%
(df_top20.groupby('Hospital')['Name']
.count()
.reset_index()
.sort_values('Name',ascending=False)
)
# Out:
#          Hospital  Name
# 10      LLC Smith    40
# 17      Smith Ltd    35
# 8     Johnson PLC    35
# 11      Ltd Smith    35
# 18      Smith PLC    33
# 14    Smith Group    32
# 3     Group Smith    30
# 15      Smith Inc    29
# 7     Johnson Inc    29
# 16      Smith LLC    28
# 9     LLC Johnson    28
# 13   PLC Williams    27
# 0       Brown Inc    26
# 12      PLC Smith    26
# 4       Inc Brown    25
# 6       Inc Smith    25
# 19   Williams LLC    25
# 1       Brown LLC    24
# 2   Group Johnson    24
# 5     Inc Johnson    24

# %%
help(df_top20.pivot_table)
# Out:
# Help on method pivot_table in module pandas.core.frame:
#
# pivot_table(
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc: 'AggFuncType' = 'mean',
#     fill_value=None,
#     margins: 'bool' = False,
#     dropna: 'bool' = True,
#     margins_name: 'Level' = 'All',
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     sort: 'bool' = True
# ) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects
#     (hierarchical indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     values : list-like or scalar, optional
#         Column or columns to aggregate.
#     index : column, Grouper, array, or list of the previous
#         Keys to group by on the pivot table index. If a list is passed,
#         it can contain any of the other types (except list). If an array is
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results', 'lenght Of Stay'],
#       dtype='object')

# %%
(df_top20.groupby('Insurance Provider')['Hospital']
.nunique()
.reset_index()
.sort_values('Hospital',ascending=False)
)
# Out:
#   Insurance Provider  Hospital
# 0              Aetna        20
# 1         Blue Cross        20
# 2              Cigna        20
# 3           Medicare        20
# 4   UnitedHealthcare        20

# %%
hospital_lists = (
    df_top20
    .groupby('Insurance Provider')['Hospital']
    .unique()
    .reset_index()
)

print(hospital_lists)
# Out:
#   Insurance Provider                                           Hospital
# 0              Aetna  [Ltd Smith, Williams LLC, Brown LLC, PLC Willi...
# 1         Blue Cross  [Brown LLC, Group Smith, PLC Smith, PLC Willia...
# 2              Cigna  [PLC Williams, LLC Smith, Smith LLC, Smith Ltd...
# 3           Medicare  [Johnson PLC, LLC Johnson, Ltd Smith, Williams...
# 4   UnitedHealthcare  [Brown LLC, Inc Smith, Smith PLC, Smith Inc, S...

# %%
hospital_counts = (
    df_top20
    .groupby('Insurance Provider')['Hospital']
    .nunique()
    .reset_index()
    .rename(columns={'Hospital': 'Unique Hospitals'})
    .sort_values('Unique Hospitals', ascending=False)
)

print(hospital_counts)
# Out:
#   Insurance Provider  Unique Hospitals
# 0              Aetna                20
# 1         Blue Cross                20
# 2              Cigna                20
# 3           Medicare                20
# 4   UnitedHealthcare                20

# %%
df_top20.to_csv('Top20hospitals.csv',index=True)

# %%
df = pd.read_csv(r'..\data\Top20hospitals.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Gender', 'Blood Type',
#        'Medical Condition', 'Date of Admission', 'Doctor', 'Hospital',
#        'Insurance Provider', 'Billing Amount', 'Room Number', 'Admission Type',
#        'Discharge Date', 'Medication', 'Test Results', 'lenght Of Stay'],
#       dtype='object')

# %%
df.rename(columns={'Unnamed: 0':'ID'},inplace=True)

# %% [markdown]
# ### Total Patients

# %%
Total_patients=(
df['Name'].nunique()
)
print(Total_patients)
# Out:
# 580

# %% [markdown]
# ### Describe the dataframe

# %%
df.describe(include='all')
# Out:
#                   ID                Name         Age  Gender Blood Type  \
# count     580.000000                 580  580.000000     580        580
# unique           NaN                 580         NaN       2          8
# top              NaN  jeFfErY WIlliaMSOn         NaN  Female         B-
# freq             NaN                   1         NaN     313         90
# mean    25040.665517                 NaN   50.798276     NaN        NaN
# std     14183.119716                 NaN   19.332175     NaN        NaN
# min       232.000000                 NaN   18.000000     NaN        NaN
# 25%     13258.500000                 NaN   34.000000     NaN        NaN
# 50%     25928.500000                 NaN   52.000000     NaN        NaN
# 75%     35910.500000                 NaN   66.250000     NaN        NaN
# max     49976.000000                 NaN   85.000000     NaN        NaN
#
#        Medical Condition Date of Admission       Doctor   Hospital  \
# ...

# %% [markdown]
# ### Average Age

# %%
Average_Age=df['Age'].mean().round(1)
print(Average_Age)
# Out:
# 50.8

# %%
avg_age = round(df['Age'].mean(), 1)
avg_age
# Out:
# np.float64(50.8)

# %% [markdown]
# ### AverageStay

# %%
df.drop('lenght Of Stay',axis=1,inplace=True)

# %%
df['Date of Admission']=pd.to_datetime(df['Date of Admission'],errors='coerce')

# %%
df['Discharge Date']=pd.to_datetime(df['Discharge Date'],errors='coerce')

# %%
df.dtypes
# Out:
# ID                             int64
# Name                          object
# Age                            int64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                    int64
# Admission Type                object
# Discharge Date        datetime64[ns]
# Medication                    object
# Test Results                  object
# dtype: object

# %%
df['Lenght Of Stay']=df['Discharge Date']-df['Date of Admission']

# %%
df.describe(include='all')
# Out:
#                   ID                Name         Age  Gender Blood Type  \
# count     580.000000                 580  580.000000     580        580
# unique           NaN                 580         NaN       2          8
# top              NaN  jeFfErY WIlliaMSOn         NaN  Female         B-
# freq             NaN                   1         NaN     313         90
# mean    25040.665517                 NaN   50.798276     NaN        NaN
# min       232.000000                 NaN   18.000000     NaN        NaN
# 25%     13258.500000                 NaN   34.000000     NaN        NaN
# 50%     25928.500000                 NaN   52.000000     NaN        NaN
# 75%     35910.500000                 NaN   66.250000     NaN        NaN
# max     49976.000000                 NaN   85.000000     NaN        NaN
# std     14183.119716                 NaN   19.332175     NaN        NaN
#
#        Medical Condition              Date of Admission       Doctor  \
# ...

# %%
average_Stay=df["Lenght Of Stay"].mean().days
average_Stay
# Out:
# 15

# %% [markdown]
# ### gender_precentage

# %%
fig_gender=px.pie(data_frame=df,names='Gender')
fig_gender.update_traces(
    textposition='inside',
    textinfo='label+percent'   # options: 'label', 'percent', 'value', 'none'
)

fig_gender.show()
